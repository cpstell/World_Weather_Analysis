# %%
# Import dependencies (python)
# pip install citipy if needed

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# add citipy library
from citipy import citipy

# add requests module
import requests

# import API key from config.py
from config import api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# From Module 6.1.4 
# Create a set of random lat and long cobinations
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# The zip method combines lats and longs into a list of pairs
lat_lngs = zip(lats, lngs)
lat_lngs


# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# From Module 6.1.5

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
# print(url)

# %%
# From Moduule 6.2.6
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
      
    # From Module 6.2.6
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # add current_description variable
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": current_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | bilma
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | alexandria
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | coquimbo
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | burnie
# Processing Record 16 of Set 1 | shimoda
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | viedma
# Processing Record 20 of Set 1 | ahipara
# Processing Record 21 of Set 1 | termoli
# Processing Record 22 of Set 1 | luziania
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | shakiso
# Processing Record 25 of Set 1 | alice springs
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | terme
# Processing Record 28 of Set 1 | krasnoselkup
# Processing Record 29 of Set 1 | batemans bay
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | kaeo
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | manjeshwar
# Processing Record 35 of Set 1 | weyburn
# Processing Record 36 of Set 1 | batagay-alyta
# Processing Record 37 of Set 1 | nemuro
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | kostino
# Processing Record 40 of Set 1 | tasca
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | yazman
# Processing Record 46 of Set 1 | salalah
# Processing Record 47 of Set 1 | qrendi
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | constitucion
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | naqadeh
# Processing Record 4 of Set 2 | elk city
# Processing Record 5 of Set 2 | broken hill
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | lorengau
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | neyshabur
# Processing Record 10 of Set 2 | shitanjing
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | wellington
# Processing Record 15 of Set 2 | ouango
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | pitimbu
# Processing Record 19 of Set 2 | arlit
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | vostok
# Processing Record 22 of Set 2 | itarema
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | arrifes
# Processing Record 25 of Set 2 | quelimane
# Processing Record 26 of Set 2 | lagos
# Processing Record 27 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 28 of Set 2 | varzea da palma
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | broome
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | micheweni
# Processing Record 33 of Set 2 | tilichiki
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 2 | pavlivka
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | alto araguaia
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | coruripe
# Processing Record 41 of Set 2 | hurghada
# Processing Record 42 of Set 2 | srednekolymsk
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | gorele
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | ambatolampy
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | yerofey pavlovich
# Processing Record 1 of Set 3 | altay
# Processing Record 2 of Set 3 | kadambur
# Processing Record 3 of Set 3 | hecun
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | komsomolskiy
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | moron
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | zlobin
# Processing Record 11 of Set 3 | ketchikan
# Processing Record 12 of Set 3 | dudinka
# Processing Record 13 of Set 3 | madang
# Processing Record 14 of Set 3 | liling
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | ancud
# Processing Record 17 of Set 3 | montepuez
# Processing Record 18 of Set 3 | inirida
# Processing Record 19 of Set 3 | kasempa
# Processing Record 20 of Set 3 | carndonagh
# Processing Record 21 of Set 3 | igra
# Processing Record 22 of Set 3 | barmer
# Processing Record 23 of Set 3 | cap malheureux
# Processing Record 24 of Set 3 | takoradi
# Processing Record 25 of Set 3 | henzada
# City not found. Skipping...
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | bembibre
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | evensk
# Processing Record 31 of Set 3 | toul
# Processing Record 32 of Set 3 | marsh harbour
# Processing Record 33 of Set 3 | maceio
# Processing Record 34 of Set 3 | pakhtakoron
# Processing Record 35 of Set 3 | san joaquin
# Processing Record 36 of Set 3 | leningradskiy
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | mandapam
# Processing Record 39 of Set 3 | sun city west
# Processing Record 40 of Set 3 | linapacan
# City not found. Skipping...
# Processing Record 41 of Set 3 | rakhya
# City not found. Skipping...
# Processing Record 42 of Set 3 | waddan
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | touros
# Processing Record 45 of Set 3 | zhigansk
# Processing Record 46 of Set 3 | digby
# Processing Record 47 of Set 3 | kinablangan
# Processing Record 48 of Set 3 | fairlie
# Processing Record 49 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | tarko-sale
# Processing Record 3 of Set 4 | auki
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 4 | emerald
# Processing Record 9 of Set 4 | along
# Processing Record 10 of Set 4 | tamandare
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | turkistan
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | jamestown
# Processing Record 15 of Set 4 | galle
# Processing Record 16 of Set 4 | petatlan
# Processing Record 17 of Set 4 | alice
# Processing Record 18 of Set 4 | college
# Processing Record 19 of Set 4 | tanete
# Processing Record 20 of Set 4 | wad rawah
# Processing Record 21 of Set 4 | alugan
# Processing Record 22 of Set 4 | zhuhai
# Processing Record 23 of Set 4 | esperance
# Processing Record 24 of Set 4 | banda aceh
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | cidreira
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | leh
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | tuatapere
# Processing Record 32 of Set 4 | chelno-vershiny
# Processing Record 33 of Set 4 | trstena
# Processing Record 34 of Set 4 | mayumba
# Processing Record 35 of Set 4 | terrace
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | sao jose da coroa grande
# Processing Record 38 of Set 4 | areka
# Processing Record 39 of Set 4 | nanakuli
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | honningsvag
# Processing Record 42 of Set 4 | marolambo
# Processing Record 43 of Set 4 | klaksvik
# Processing Record 44 of Set 4 | yakeshi
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | suntar
# Processing Record 47 of Set 4 | fort nelson
# Processing Record 48 of Set 4 | argos
# Processing Record 49 of Set 4 | sitka
# Processing Record 50 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | dolores
# Processing Record 2 of Set 5 | saldanha
# Processing Record 3 of Set 5 | chuy
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | dunedin
# Processing Record 6 of Set 5 | shenjiamen
# Processing Record 7 of Set 5 | hilo
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | luganville
# Processing Record 10 of Set 5 | abonnema
# Processing Record 11 of Set 5 | gat
# Processing Record 12 of Set 5 | yar-sale
# Processing Record 13 of Set 5 | antalaha
# Processing Record 14 of Set 5 | sambava
# Processing Record 15 of Set 5 | kodiak
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | abalak
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | stokmarknes
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | sao filipe
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | chumphon
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | tual
# Processing Record 28 of Set 5 | alakurtti
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | haines junction
# Processing Record 31 of Set 5 | olinda
# Processing Record 32 of Set 5 | sobolevo
# Processing Record 33 of Set 5 | sapa
# Processing Record 34 of Set 5 | lata
# Processing Record 35 of Set 5 | karoi
# Processing Record 36 of Set 5 | saint-georges
# Processing Record 37 of Set 5 | nakuru
# Processing Record 38 of Set 5 | anloga
# Processing Record 39 of Set 5 | paamiut
# Processing Record 40 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | adre
# Processing Record 43 of Set 5 | harper
# Processing Record 44 of Set 5 | homer
# Processing Record 45 of Set 5 | kamenka
# Processing Record 46 of Set 5 | rocha
# Processing Record 47 of Set 5 | soe
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | ajdabiya
# Processing Record 50 of Set 5 | tura
# Processing Record 1 of Set 6 | macomer
# Processing Record 2 of Set 6 | port hedland
# Processing Record 3 of Set 6 | udachnyy
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | chapais
# Processing Record 6 of Set 6 | zaykovo
# Processing Record 7 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 6 | carlos antonio lopez
# Processing Record 9 of Set 6 | tiksi
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | alofi
# Processing Record 12 of Set 6 | san patricio
# Processing Record 13 of Set 6 | butaritari
# Processing Record 14 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 6 | chico
# Processing Record 16 of Set 6 | madimba
# Processing Record 17 of Set 6 | esna
# Processing Record 18 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 6 | lincoln
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | kieta
# Processing Record 22 of Set 6 | qaqortoq
# Processing Record 23 of Set 6 | katangli
# Processing Record 24 of Set 6 | chirongui
# Processing Record 25 of Set 6 | myanaung
# Processing Record 26 of Set 6 | okha
# Processing Record 27 of Set 6 | turukhansk
# Processing Record 28 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 29 of Set 6 | giddarbaha
# Processing Record 30 of Set 6 | tasiilaq
# Processing Record 31 of Set 6 | mizdah
# Processing Record 32 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 6 | lufilufi
# Processing Record 34 of Set 6 | behshahr
# Processing Record 35 of Set 6 | sangar
# Processing Record 36 of Set 6 | garowe
# Processing Record 37 of Set 6 | fukue
# Processing Record 38 of Set 6 | smolenka
# Processing Record 39 of Set 6 | shu
# Processing Record 40 of Set 6 | kruisfontein
# Processing Record 41 of Set 6 | aitape
# Processing Record 42 of Set 6 | terney
# Processing Record 43 of Set 6 | bosaso
# Processing Record 44 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 6 | slave lake
# Processing Record 46 of Set 6 | santa lucia
# Processing Record 47 of Set 6 | huadian
# Processing Record 48 of Set 6 | burica
# City not found. Skipping...
# Processing Record 49 of Set 6 | troyes
# Processing Record 50 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 1 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 7 | pyinmana
# Processing Record 3 of Set 7 | san quintin
# Processing Record 4 of Set 7 | vila velha
# Processing Record 5 of Set 7 | san policarpo
# Processing Record 6 of Set 7 | avera
# Processing Record 7 of Set 7 | kenai
# Processing Record 8 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 7 | queanbeyan
# Processing Record 10 of Set 7 | dzerzhinskoye
# Processing Record 11 of Set 7 | panama city
# Processing Record 12 of Set 7 | grindavik
# Processing Record 13 of Set 7 | kuala terengganu
# Processing Record 14 of Set 7 | concarneau
# Processing Record 15 of Set 7 | ciudad bolivar
# Processing Record 16 of Set 7 | les cayes
# Processing Record 17 of Set 7 | mogadishu
# Processing Record 18 of Set 7 | morgan city
# Processing Record 19 of Set 7 | matamoros
# Processing Record 20 of Set 7 | half moon bay
# Processing Record 21 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | samarai
# Processing Record 24 of Set 7 | laureles
# Processing Record 25 of Set 7 | sorland
# Processing Record 26 of Set 7 | guhagar
# Processing Record 27 of Set 7 | trelew
# Processing Record 28 of Set 7 | willowmore
# Processing Record 29 of Set 7 | dikson
# Processing Record 30 of Set 7 | sassandra
# Processing Record 31 of Set 7 | mildura
# Processing Record 32 of Set 7 | bemidji
# Processing Record 33 of Set 7 | san andres
# Processing Record 34 of Set 7 | hanzhong
# Processing Record 35 of Set 7 | abu dhabi
# Processing Record 36 of Set 7 | norman wells
# Processing Record 37 of Set 7 | danilovka
# Processing Record 38 of Set 7 | byron bay
# Processing Record 39 of Set 7 | aksarka
# Processing Record 40 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | maumere
# Processing Record 43 of Set 7 | atocha
# Processing Record 44 of Set 7 | beloha
# Processing Record 45 of Set 7 | yomou
# Processing Record 46 of Set 7 | fortuna
# Processing Record 47 of Set 7 | amahai
# Processing Record 48 of Set 7 | mahibadhoo
# Processing Record 49 of Set 7 | hofn
# Processing Record 50 of Set 7 | kerouane
# Processing Record 1 of Set 8 | atar
# Processing Record 2 of Set 8 | muroto
# Processing Record 3 of Set 8 | khuzhir
# Processing Record 4 of Set 8 | southbridge
# Processing Record 5 of Set 8 | hualmay
# Processing Record 6 of Set 8 | wonosobo
# Processing Record 7 of Set 8 | brae
# Processing Record 8 of Set 8 | northam
# Processing Record 9 of Set 8 | codrington
# Processing Record 10 of Set 8 | kabalo
# Processing Record 11 of Set 8 | morrinhos
# Processing Record 12 of Set 8 | benguela
# Processing Record 13 of Set 8 | kasane
# Processing Record 14 of Set 8 | rawson
# Processing Record 15 of Set 8 | korla
# Processing Record 16 of Set 8 | kuteynykove
# Processing Record 17 of Set 8 | bulgan
# Processing Record 18 of Set 8 | margate
# Processing Record 19 of Set 8 | oeiras do para
# Processing Record 20 of Set 8 | kyzyl-suu
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | hamilton
# Processing Record 23 of Set 8 | voznesenye
# Processing Record 24 of Set 8 | chokurdakh
# Processing Record 25 of Set 8 | saint-augustin
# Processing Record 26 of Set 8 | royan
# Processing Record 27 of Set 8 | gwembe
# Processing Record 28 of Set 8 | okmulgee
# Processing Record 29 of Set 8 | masindi
# Processing Record 30 of Set 8 | icod de los vinos
# Processing Record 31 of Set 8 | parkes
# Processing Record 32 of Set 8 | bakchar
# Processing Record 33 of Set 8 | redlands
# Processing Record 34 of Set 8 | goure
# Processing Record 35 of Set 8 | vilyuysk
# Processing Record 36 of Set 8 | tsalenjikha
# Processing Record 37 of Set 8 | mitchell
# Processing Record 38 of Set 8 | djibo
# Processing Record 39 of Set 8 | abapo
# Processing Record 40 of Set 8 | moissala
# Processing Record 41 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 8 | asau
# Processing Record 43 of Set 8 | nabire
# Processing Record 44 of Set 8 | colares
# Processing Record 45 of Set 8 | hami
# Processing Record 46 of Set 8 | rudnogorsk
# Processing Record 47 of Set 8 | jibuti
# Processing Record 48 of Set 8 | abnub
# Processing Record 49 of Set 8 | dok kham tai
# Processing Record 50 of Set 8 | sioux lookout
# Processing Record 1 of Set 9 | atlantis
# Processing Record 2 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 9 | puerto ayacucho
# Processing Record 4 of Set 9 | kanina
# Processing Record 5 of Set 9 | majene
# Processing Record 6 of Set 9 | san julian
# Processing Record 7 of Set 9 | forbes
# Processing Record 8 of Set 9 | haldibari
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | longavi
# Processing Record 11 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 9 | banepa
# Processing Record 14 of Set 9 | naantali
# Processing Record 15 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 9 | aswan
# Processing Record 17 of Set 9 | manbij
# Processing Record 18 of Set 9 | claremore
# Processing Record 19 of Set 9 | cradock
# Processing Record 20 of Set 9 | elko
# Processing Record 21 of Set 9 | dourbali
# Processing Record 22 of Set 9 | fairfield
# Processing Record 23 of Set 9 | muzhi
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | aykhal
# Processing Record 26 of Set 9 | gulu
# Processing Record 27 of Set 9 | nikolskoye
# Processing Record 28 of Set 9 | bayan
# Processing Record 29 of Set 9 | puerto cabello
# Processing Record 30 of Set 9 | kahului
# Processing Record 31 of Set 9 | mount gambier
# Processing Record 32 of Set 9 | gawler
# Processing Record 33 of Set 9 | eurajoki
# Processing Record 34 of Set 9 | skibbereen
# Processing Record 35 of Set 9 | belmonte
# Processing Record 36 of Set 9 | valsamata
# Processing Record 37 of Set 9 | bandarbeyla
# Processing Record 38 of Set 9 | mangaratiba
# Processing Record 39 of Set 9 | alcudia
# Processing Record 40 of Set 9 | thionville
# Processing Record 41 of Set 9 | armidale
# Processing Record 42 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 9 | deputatskiy
# Processing Record 44 of Set 9 | rybnoye
# Processing Record 45 of Set 9 | henties bay
# Processing Record 46 of Set 9 | champerico
# Processing Record 47 of Set 9 | khorixas
# Processing Record 48 of Set 9 | khandela
# Processing Record 49 of Set 9 | kudahuvadhoo
# Processing Record 50 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 10 | keflavik
# Processing Record 2 of Set 10 | toufen
# Processing Record 3 of Set 10 | oktyabrskiy
# Processing Record 4 of Set 10 | kangaatsiaq
# Processing Record 5 of Set 10 | hellvik
# Processing Record 6 of Set 10 | moerai
# Processing Record 7 of Set 10 | tabou
# Processing Record 8 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 9 of Set 10 | kurchum
# Processing Record 10 of Set 10 | ergani
# Processing Record 11 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 10 | mweka
# Processing Record 13 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 14 of Set 10 | ternate
# Processing Record 15 of Set 10 | rock springs
# Processing Record 16 of Set 10 | guarapari
# Processing Record 17 of Set 10 | port-gentil
# Processing Record 18 of Set 10 | carutapera
# Processing Record 19 of Set 10 | janesville
# Processing Record 20 of Set 10 | bonfim
# Processing Record 21 of Set 10 | bahia de caraquez
# Processing Record 22 of Set 10 | najran
# Processing Record 23 of Set 10 | bubaque
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | moose factory
# Processing Record 26 of Set 10 | husavik
# Processing Record 27 of Set 10 | great falls
# Processing Record 28 of Set 10 | sibolga
# Processing Record 29 of Set 10 | buchanan
# Processing Record 30 of Set 10 | guerrero negro
# Processing Record 31 of Set 10 | umea
# Processing Record 32 of Set 10 | corowa
# Processing Record 33 of Set 10 | vanavara
# Processing Record 34 of Set 10 | hvolsvollur
# Processing Record 35 of Set 10 | tha mai
# Processing Record 36 of Set 10 | sinnamary
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | buala
# Processing Record 39 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 40 of Set 10 | lompoc
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | los llanos de aridane
# Processing Record 43 of Set 10 | kaabong
# Processing Record 44 of Set 10 | nisia floresta
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | maralal
# Processing Record 47 of Set 10 | meulaboh
# Processing Record 48 of Set 10 | bonthe
# Processing Record 49 of Set 10 | conceicao do araguaia
# Processing Record 50 of Set 10 | binzhou
# Processing Record 1 of Set 11 | vanimo
# Processing Record 2 of Set 11 | tamworth
# Processing Record 3 of Set 11 | la uribe
# City not found. Skipping...
# Processing Record 4 of Set 11 | anderson
# Processing Record 5 of Set 11 | colesberg
# Processing Record 6 of Set 11 | guaratingueta
# Processing Record 7 of Set 11 | coahuayana
# Processing Record 8 of Set 11 | tianpeng
# Processing Record 9 of Set 11 | fare
# Processing Record 10 of Set 11 | cayenne
# Processing Record 11 of Set 11 | redmond
# Processing Record 12 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 13 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 11 | sovetskiy
# Processing Record 15 of Set 11 | ixtapa
# Processing Record 16 of Set 11 | tirunelveli
# Processing Record 17 of Set 11 | mandan
# Processing Record 18 of Set 11 | porbandar
# Processing Record 19 of Set 11 | santa maria
# Processing Record 20 of Set 11 | boa vista
# Processing Record 21 of Set 11 | salym
# Processing Record 22 of Set 11 | bulungu
# Processing Record 23 of Set 11 | qui nhon
# Processing Record 24 of Set 11 | bilibino
# Processing Record 25 of Set 11 | riyadh
# Processing Record 26 of Set 11 | praia da vitoria
# Processing Record 27 of Set 11 | capinopolis
# Processing Record 28 of Set 11 | te anau
# Processing Record 29 of Set 11 | kirakira
# Processing Record 30 of Set 11 | saint paul
# Processing Record 31 of Set 11 | mount isa
# Processing Record 32 of Set 11 | vitoria
# Processing Record 33 of Set 11 | lubao
# Processing Record 34 of Set 11 | sharjah
# Processing Record 35 of Set 11 | suffolk
# Processing Record 36 of Set 11 | mangrol
# Processing Record 37 of Set 11 | nueva germania
# Processing Record 38 of Set 11 | minab
# Processing Record 39 of Set 11 | muisne
# Processing Record 40 of Set 11 | ilinge
# Processing Record 41 of Set 11 | rabo de peixe
# Processing Record 42 of Set 11 | chivay
# Processing Record 43 of Set 11 | leshukonskoye
# Processing Record 44 of Set 11 | pacifica
# Processing Record 45 of Set 11 | chupei
# City not found. Skipping...
# Processing Record 46 of Set 11 | shelopugino
# Processing Record 47 of Set 11 | mao
# Processing Record 48 of Set 11 | taltal
# Processing Record 49 of Set 11 | outjo
# Processing Record 50 of Set 11 | shaoxing
# Processing Record 1 of Set 12 | ust-ilimsk
# Processing Record 2 of Set 12 | bud
# Processing Record 3 of Set 12 | catuday
# Processing Record 4 of Set 12 | dingle
# Processing Record 5 of Set 12 | tandil
# Processing Record 6 of Set 12 | gap
# Processing Record 7 of Set 12 | morehead
# Processing Record 8 of Set 12 | severo-yeniseyskiy
# Processing Record 9 of Set 12 | poum
# Processing Record 10 of Set 12 | arica
# Processing Record 11 of Set 12 | santa rosa
# Processing Record 12 of Set 12 | luancheng
# Processing Record 13 of Set 12 | pareora
# Processing Record 14 of Set 12 | lavrentiya
# Processing Record 15 of Set 12 | luderitz
# Processing Record 16 of Set 12 | dossor
# Processing Record 17 of Set 12 | tecoanapa
# Processing Record 18 of Set 12 | boende
# Processing Record 19 of Set 12 | praia
# Processing Record 20 of Set 12 | san carlos de bariloche
# Processing Record 21 of Set 12 | chavakachcheri
# Processing Record 22 of Set 12 | staryy nadym
# Processing Record 23 of Set 12 | palu
# Processing Record 24 of Set 12 | san luis
# Processing Record 25 of Set 12 | morondava
# Processing Record 26 of Set 12 | rosehearty
# Processing Record 27 of Set 12 | linqiong
# Processing Record 28 of Set 12 | martapura
# Processing Record 29 of Set 12 | pemba
# Processing Record 30 of Set 12 | port hardy
# Processing Record 31 of Set 12 | havelock
# Processing Record 32 of Set 12 | minsk
# Processing Record 33 of Set 12 | manokwari
# Processing Record 34 of Set 12 | waingapu
# Processing Record 35 of Set 12 | nipawin
# Processing Record 36 of Set 12 | dukat
# Processing Record 37 of Set 12 | wairoa
# Processing Record 38 of Set 12 | knysna
# Processing Record 39 of Set 12 | mantua
# Processing Record 40 of Set 12 | aden
# Processing Record 41 of Set 12 | kautokeino
# Processing Record 42 of Set 12 | arman
# Processing Record 43 of Set 12 | shantipur
# Processing Record 44 of Set 12 | arnedo
# Processing Record 45 of Set 12 | isla mujeres
# Processing Record 46 of Set 12 | jalingo
# Processing Record 47 of Set 12 | pisco
# Processing Record 48 of Set 12 | nicoya
# Processing Record 49 of Set 12 | kisanga
# Processing Record 50 of Set 12 | mokhotlong
# Processing Record 1 of Set 13 | troitsko-pechorsk
# Processing Record 2 of Set 13 | kushmurun
# Processing Record 3 of Set 13 | tezu
# Processing Record 4 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 13 | yumen
# Processing Record 6 of Set 13 | issoudun
# Processing Record 7 of Set 13 | loiza
# Processing Record 8 of Set 13 | karratha
# Processing Record 9 of Set 13 | cacu
# Processing Record 10 of Set 13 | vila franca do campo
# Processing Record 11 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 13 | prince rupert
# Processing Record 13 of Set 13 | nortelandia
# Processing Record 14 of Set 13 | nouadhibou
# Processing Record 15 of Set 13 | oktyabrskoye
# Processing Record 16 of Set 13 | phan thiet
# Processing Record 17 of Set 13 | quimper
# Processing Record 18 of Set 13 | krutikha
# Processing Record 19 of Set 13 | mbigou
# Processing Record 20 of Set 13 | vaitape
# Processing Record 21 of Set 13 | ballangen
# Processing Record 22 of Set 13 | yefimovskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | sept-iles
# Processing Record 24 of Set 13 | west bay
# Processing Record 25 of Set 13 | souillac
# Processing Record 26 of Set 13 | vao
# Processing Record 27 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 13 | gazli
# Processing Record 29 of Set 13 | bojnurd
# Processing Record 30 of Set 13 | ahuimanu
# Processing Record 31 of Set 13 | vestmannaeyjar
# Processing Record 32 of Set 13 | llanes
# Processing Record 33 of Set 13 | honiara
# Processing Record 34 of Set 13 | namibe
# Processing Record 35 of Set 13 | vila
# Processing Record 36 of Set 13 | wake forest
# Processing Record 37 of Set 13 | araouane
# Processing Record 38 of Set 13 | xadani
# City not found. Skipping...
# Processing Record 39 of Set 13 | mishan
# Processing Record 40 of Set 13 | krionerion
# City not found. Skipping...
# Processing Record 41 of Set 13 | oyama
# Processing Record 42 of Set 13 | ust-koksa
# Processing Record 43 of Set 13 | frankfort
# Processing Record 44 of Set 13 | nelson bay
# Processing Record 45 of Set 13 | ruidoso
# Processing Record 46 of Set 13 | barpali
# Processing Record 47 of Set 13 | fayaoue
# Processing Record 48 of Set 13 | sao gabriel da cachoeira
# Processing Record 49 of Set 13 | plast
# Processing Record 50 of Set 13 | dangriga
# Processing Record 1 of Set 14 | ostersund
# Processing Record 2 of Set 14 | kayankulam
# Processing Record 3 of Set 14 | cedar lake
# Processing Record 4 of Set 14 | centralia
# Processing Record 5 of Set 14 | morant bay
# Processing Record 6 of Set 14 | sola
# Processing Record 7 of Set 14 | copala
# Processing Record 8 of Set 14 | innisfail
# Processing Record 9 of Set 14 | ituiutaba
# Processing Record 10 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 14 | bassar
# Processing Record 12 of Set 14 | angoche
# Processing Record 13 of Set 14 | edd
# Processing Record 14 of Set 14 | necochea
# Processing Record 15 of Set 14 | kracheh
# City not found. Skipping...
# Processing Record 16 of Set 14 | shaoyang
# Processing Record 17 of Set 14 | jiazi
# Processing Record 18 of Set 14 | caravelas
# Processing Record 19 of Set 14 | price
# Processing Record 20 of Set 14 | mbala
# Processing Record 21 of Set 14 | hambantota
# Processing Record 22 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 14 | scicli
# Processing Record 24 of Set 14 | pinheiro machado
# Processing Record 25 of Set 14 | ruston
# Processing Record 26 of Set 14 | mookane
# Processing Record 27 of Set 14 | hun
# Processing Record 28 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 14 | mizan teferi
# Processing Record 30 of Set 14 | shirokiy
# Processing Record 31 of Set 14 | tautira
# Processing Record 32 of Set 14 | bra
# Processing Record 33 of Set 14 | kupang
# Processing Record 34 of Set 14 | xining
# Processing Record 35 of Set 14 | tikapur
# Processing Record 36 of Set 14 | porosozero
# Processing Record 37 of Set 14 | santa marinella
# Processing Record 38 of Set 14 | kuvandyk
# Processing Record 39 of Set 14 | liberal
# Processing Record 40 of Set 14 | ariquemes
# Processing Record 41 of Set 14 | pandan
# Processing Record 42 of Set 14 | longyearbyen
# Processing Record 43 of Set 14 | mutare
# Processing Record 44 of Set 14 | cabatuan
# Processing Record 45 of Set 14 | kailua
# Processing Record 46 of Set 14 | kholtoson
# Processing Record 47 of Set 14 | jiangyou
# Processing Record 48 of Set 14 | santa isabel
# Processing Record 49 of Set 14 | katherine
# Processing Record 50 of Set 14 | pergamino
# Processing Record 1 of Set 15 | benalla
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 15 | valley
# Processing Record 5 of Set 15 | pando
# Processing Record 6 of Set 15 | ibiapina
# Processing Record 7 of Set 15 | fairbanks
# Processing Record 8 of Set 15 | san antonio
# Processing Record 9 of Set 15 | pak kret
# Processing Record 10 of Set 15 | tazovskiy
# Processing Record 11 of Set 15 | namatanai
# Processing Record 12 of Set 15 | mwinilunga
# Processing Record 13 of Set 15 | baruun-urt
# Processing Record 14 of Set 15 | bonavista
# Processing Record 15 of Set 15 | prabumulih
# Processing Record 16 of Set 15 | disna
# Processing Record 17 of Set 15 | dondo
# Processing Record 18 of Set 15 | prado
# Processing Record 19 of Set 15 | laguna
# Processing Record 20 of Set 15 | balkany
# Processing Record 21 of Set 15 | roros
# Processing Record 22 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 15 | alyangula
# Processing Record 24 of Set 15 | rincon
# Processing Record 25 of Set 15 | canico
# Processing Record 26 of Set 15 | mindelo
# Processing Record 27 of Set 15 | acandi
# Processing Record 28 of Set 15 | laerdalsoyri
# Processing Record 29 of Set 15 | hervey bay
# Processing Record 30 of Set 15 | tambilil
# Processing Record 31 of Set 15 | pakpattan
# Processing Record 32 of Set 15 | preobrazheniye
# Processing Record 33 of Set 15 | takaka
# Processing Record 34 of Set 15 | eirunepe
# Processing Record 35 of Set 15 | kerchevskiy
# Processing Record 36 of Set 15 | pilar
# Processing Record 37 of Set 15 | ostrovnoy
# Processing Record 38 of Set 15 | maltahohe
# Processing Record 39 of Set 15 | znamenskoye
# Processing Record 40 of Set 15 | goderich
# Processing Record 41 of Set 15 | itaituba
# Processing Record 42 of Set 15 | valverde del camino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# From Module 6.2.7
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng          Current Description  Max Temp  \
# 0           Barrow  71.2906 -156.7887              overcast clouds     51.82
# 1        Busselton -33.6500  115.3333              overcast clouds     55.81
# 2   Ribeira Grande  38.5167  -28.7000                   few clouds     73.80
# 3          Rikitea -23.1203 -134.9692                    clear sky     73.35
# 4            Bilma  18.6853   12.9164                broken clouds     92.82
# 5           Albany  42.6001  -73.9662             scattered clouds     95.65
# 6  Bambous Virieux -20.3428   57.7575  light intensity shower rain     68.25
# 7          Mataura -46.1927  168.8643              overcast clouds     40.48
# 8       Bredasdorp -34.5322   20.0403                    clear sky     45.43
# 9       Alexandria  31.2156   29.9553                    clear sky     77.54
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        62         100        6.91      US  2022-07-20 21:50:08
# 1        94         100       10.02      AU  2022-07-20 21:50:09
# 2        83          20        5.75      PT  2022-07-20 21:50:09
# 3        75           0        3.98      PF  2022-07-20 21:50:09
# 4        17          73        2.86      NE  2022-07-20 21:50:09
# 5        48          47        4.00      US  2022-07-20 21:45:29
# 6        83          75       24.16      MU  2022-07-20 21:50:10
# 7        88         100        2.84      NZ  2022-07-20 21:50:10
# 8        87           1        4.99      ZA  2022-07-20 21:50:11
# 9        73           0       12.66      EG  2022-07-20 21:45:29

# %%
# From Module 6.2.7
# Reorder Data frame
new_column_order = ['City', 'Country', 'Date', 'Current Description', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                     City Country                 Date Current Description  \
# 0                 Barrow      US  2022-07-20 21:50:08     overcast clouds
# 1              Busselton      AU  2022-07-20 21:50:09     overcast clouds
# 2         Ribeira Grande      PT  2022-07-20 21:50:09          few clouds
# 3                Rikitea      PF  2022-07-20 21:50:09           clear sky
# 4                  Bilma      NE  2022-07-20 21:50:09       broken clouds
# ..                   ...     ...                  ...                 ...
# 680            Maltahohe      NA  2022-07-20 22:07:18           clear sky
# 681          Znamenskoye      RU  2022-07-20 22:07:18     overcast clouds
# 682             Goderich      CA  2022-07-20 22:07:19       broken clouds
# 683             Itaituba      BR  2022-07-20 22:07:19     overcast clouds
# 684  Valverde Del Camino      ES  2022-07-20 22:07:19           clear sky
#
#          Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    71.2906 -156.7887     51.82        62         100        6.91
# 1   -33.6500  115.3333     55.81        94         100       10.02
# 2    38.5167  -28.7000     73.80        83          20        5.75
# 3   -23.1203 -134.9692     73.35        75           0        3.98
# 4    18.6853   12.9164     92.82        17          73        2.86
# ..       ...       ...       ...       ...         ...         ...
# 680 -24.8333   16.9833     53.85        38           0        6.51
# 681  57.1281   73.8282     59.36        99          97        3.89
# 682  43.7501  -81.7165     78.91        88          75       23.20
# 683  -4.2761  -55.9836     82.11        62          98        2.15
# 684  37.5751   -6.7543     79.03        34           0        3.62
#
# [685 rows x 10 columns]

# %%
# From Module 6.2.7
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
